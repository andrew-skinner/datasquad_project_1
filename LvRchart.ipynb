# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
homeruns = [8969, 13240]
x_axis = np.arange(len(homeruns))

# %%
plt.bar(x_axis, users, color='r', alpha=0.5, align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 2 artists>

# %%
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["Left Handed", "Right Handed"])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# (-0.75, 1.75)

# %%
plt.ylim(0, max(homeruns)+5000)
# Out:
# (0, 18240)

# %%
plt.title("Homeruns Left VS Right Past 3 Years")
plt.xlabel("Hand")
plt.ylabel("Number of Homeruns")
# Out:
# Text(20.722222222222214, 0.5, 'Number of Homeruns')
